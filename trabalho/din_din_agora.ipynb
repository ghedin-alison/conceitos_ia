# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
clientes = pd.read_csv('../Clientes.csv', sep=',')
clientes.head()
# Out:
#                                     ids target_default  \
# 0  343b7e7b-2cf8-e508-b8fd-0a0285af30aa          False
# 1  bc2c7502-bbad-0f8c-39c3-94e881967124          False
# 2  669630dd-2e6a-0396-84bf-455e5009c922           True
# 3  d235609e-b6cb-0ccc-a329-d4f12e7ebdc1          False
# 4  9e0eb880-e8f4-3faa-67d8-f5cdd2b3932b          False
#
#                     score_1                   score_2  score_3     score_4  \
# 0  1Rk8w4Ucd5yR3KcqZzLdow==  IOVu8au3ISbo6+zmfnYwMg==    350.0  101.800832
# 1  DGCQep2AE5QRkNCshIAlFQ==  SaamrHMo23l/3TwXOWgVzw==    370.0   97.062615
# 2  DGCQep2AE5QRkNCshIAlFQ==  Fv28Bz0YRTVAT5kl1bAV6g==    360.0  100.027073
# 3  1Rk8w4Ucd5yR3KcqZzLdow==  dCm9hFKfdRm7ej3jW+gyxw==    510.0  101.599485
# 4  8k8UDR4Yx0qasAjkGrUZLw==  +CxEO4w7jv3QPI/BQbyqAA==    500.0   98.474289
#
#     score_5     score_6  risk_rate  last_amount_borrowed  ...  \
# 0  0.259555  108.427273       0.40              25033.92  ...
# ...

# %%
clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 43 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   ids                                               45000 non-null  object
#  1   target_default                                    41741 non-null  object
#  2   score_1                                           44438 non-null  object
#  3   score_2                                           44438 non-null  object
#  4   score_3                                           44438 non-null  float64
#  5   score_4                                           45000 non-null  float64
#  6   score_5                                           45000 non-null  float64
#  7   score_6                                           45000 non-null  float64
#  8   risk_rate                                         44438 non-null  float64
# ...

# %%
clientes.columns
# Out:
# Index(['ids', 'target_default', 'score_1', 'score_2', 'score_3', 'score_4',
#        'score_5', 'score_6', 'risk_rate', 'last_amount_borrowed',
#        'last_borrowed_in_months', 'credit_limit', 'reason', 'income',
#        'facebook_profile', 'state', 'zip', 'channel', 'job_name', 'real_state',
#        'ok_since', 'n_bankruptcies', 'n_defaulted_loans', 'n_accounts',
#        'n_issues', 'application_time_applied', 'application_time_in_funnel',
#        'email', 'external_data_provider_credit_checks_last_2_year',
#        'external_data_provider_credit_checks_last_month',
#        'external_data_provider_credit_checks_last_year',
#        'external_data_provider_email_seen_before',
#        'external_data_provider_first_name',
#        'external_data_provider_fraud_score', 'lat_lon', 'marketing_channel',
#        'profile_phone_number', 'reported_income', 'shipping_state',
#        'shipping_zip_code', 'profile_tags', 'user_agent', 'target_fraud'],
#       dtype='object')

# %%
len(clientes.columns)
# Out:
# 43

# %% [markdown]
# ## Análise das informações

# %%
clientes.iloc[:10, :10]
# Out:
#                                     ids target_default  \
# 0  343b7e7b-2cf8-e508-b8fd-0a0285af30aa          False
# 1  bc2c7502-bbad-0f8c-39c3-94e881967124          False
# 2  669630dd-2e6a-0396-84bf-455e5009c922           True
# 3  d235609e-b6cb-0ccc-a329-d4f12e7ebdc1          False
# 4  9e0eb880-e8f4-3faa-67d8-f5cdd2b3932b          False
# 5  538c1908-bd80-b834-c3f0-238b4f536d3f          False
# 6  cd23a767-efe7-46fe-18c7-59b93f2e6e72          False
# 7  7552f149-5c7b-9e10-24a0-55978ee4ff5b          False
# 8  2bf379e3-51e3-2f7c-168f-3d494e2d2b5b          False
# 9  4146cbf8-1ec5-f381-e5c4-1ffad3a3e37e           True
#
#                     score_1                   score_2  score_3     score_4  \
# 0  1Rk8w4Ucd5yR3KcqZzLdow==  IOVu8au3ISbo6+zmfnYwMg==    350.0  101.800832
# 1  DGCQep2AE5QRkNCshIAlFQ==  SaamrHMo23l/3TwXOWgVzw==    370.0   97.062615
# 2  DGCQep2AE5QRkNCshIAlFQ==  Fv28Bz0YRTVAT5kl1bAV6g==    360.0  100.027073
# ...

# %%
clientes.iloc[:10, 10:15]
# Out:
#    last_borrowed_in_months  credit_limit  \
# 0                     36.0           0.0
# 1                      NaN       39726.0
# 2                     36.0           NaN
# 3                      NaN       54591.0
# 4                      NaN           NaN
# 5                      NaN       61055.0
# 6                      NaN           NaN
# 7                      NaN       42666.0
# 8                     60.0           NaN
# 9                      NaN       16291.0
#
#                                               reason     income  \
# 0  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...   65014.12
# 1  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...  100018.91
# 2  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...   65023.65
# 3  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...   68830.01
# 4  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...   60011.29
# 5  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...   75024.28
# ...

# %%
clientes.iloc[:10, 15:20]
# Out:
#                       state                       zip  \
# 0  sjJbkqJS7cXalHLBFA+EOQ==  Ernn+uVXCMq/6ARrBCcd+A==
# 1  xsd3ZdsI3356I3xMxZeiqQ==  rlWIXTBO+VOa34+SpGyhlQ==
# 2  Ygq6MsM98oC8yceExr69Ig==  PjTIDfJsK0DKL9fO7vuW2g==
# 3  KET/Pmr6rHp1RJ/P9ymztw==  Cc/kWDLQH3dpHv5HU+pLVA==
# 4  xsd3ZdsI3356I3xMxZeiqQ==  i036nmJ7rfxo+3EvCD7Jnw==
# 5  JrdZzPZEa/YIIGwh8OdTKA==  kfWDI5wYFHdi9PtKFI9EPg==
# 6  xsd3ZdsI3356I3xMxZeiqQ==  3k2JCQ8Bp5oDwaI39ZJgHA==
# 7  orU7WJYGPT/xFwOXY1eBkw==  kT9iINxmEtNoxGqiEuuu1w==
# 8  xsd3ZdsI3356I3xMxZeiqQ==  IS7hpLnmcFmoFQx5fYolyA==
# 9  P1TKs1aii8osbgO+MszZ2w==  FcreDj8X5CjkLfqOjlBKIQ==
#
#                     channel  \
# 0  NCqL3QBx0pscDnx3ixKwXg==
# 1  NCqL3QBx0pscDnx3ixKwXg==
# 2  NCqL3QBx0pscDnx3ixKwXg==
# 3  NCqL3QBx0pscDnx3ixKwXg==
# 4  NCqL3QBx0pscDnx3ixKwXg==
# 5  NCqL3QBx0pscDnx3ixKwXg==
# 6  NCqL3QBx0pscDnx3ixKwXg==
# 7  NCqL3QBx0pscDnx3ixKwXg==
# 8  NCqL3QBx0pscDnx3ixKwXg==
# 9  NCqL3QBx0pscDnx3ixKwXg==
#
# ...

# %%
clientes.iloc[:10, 20:25]
# Out:
#    ok_since  n_bankruptcies  n_defaulted_loans  n_accounts  n_issues
# 0       NaN             0.0                0.0        18.0      18.0
# 1      50.0             0.0                0.0        14.0      14.0
# 2       NaN             0.0                0.0        10.0       NaN
# 3       NaN             1.0                0.0        19.0      19.0
# 4       NaN             0.0                0.0        11.0       NaN
# 5       NaN             0.0                0.0         9.0       9.0
# 6       NaN             0.0                0.0         8.0       NaN
# 7       NaN             0.0                0.0         7.0       7.0
# 8       NaN             0.0                0.0         8.0       NaN
# 9       NaN             0.0                0.0         8.0       8.0

# %%
clientes.iloc[:10, 25:30]
# Out:
#   application_time_applied  application_time_in_funnel        email  \
# 0                 07:52:34                         444  outlook.com
# 1                 02:34:29                         346    gmail.com
# 2                 00:60:02                           6    gmail.com
# 3                 11:20:49                         406    spgov.com
# 4                 13:39:03                         240    gmail.com
# 5                 05:27:02                         169    gmail.com
# 6                 08:19:45                          74    gmail.com
# 7                 17:58:42                         184  outlook.com
# 8                 15:04:47                         420    spgov.com
# 9                 04:47:22                           7  hotmail.com
#
#    external_data_provider_credit_checks_last_2_year  \
# 0                                               NaN
# 1                                               0.0
# 2                                               NaN
# ...

# %%
clientes.iloc[:10, 30:35]
# Out:
#    external_data_provider_credit_checks_last_year  \
# 0                                             0.0
# 1                                             0.0
# 2                                             NaN
# 3                                             NaN
# 4                                             1.0
# 5                                             1.0
# 6                                             0.0
# 7                                             0.0
# 8                                             NaN
# 9                                             0.0
#
#    external_data_provider_email_seen_before external_data_provider_first_name  \
# 0                                      51.0                        leidelaura
# 1                                      17.0                          diocezio
# 2                                       9.0                         veralucia
# 3                                      38.0                            venice
# ...

# %%
clientes.iloc[:10, 35:44]
# Out:
#   marketing_channel profile_phone_number  reported_income shipping_state  \
# 0      Invite-email          514-9840782          57849.0          BR-MT
# 1  Radio-commercial          251-3659293           4902.0          BR-RS
# 2      Waiting-list          230-6097993         163679.0          BR-RR
# 3      Waiting-list          261-3543751           1086.0          BR-RN
# 4      Invite-email          102-3660162         198618.0          BR-MT
# 5           Website          787-1678197         160198.0          BR-SP
# 6           Twitter          185-7402507         132928.0          BR-SP
# 7      Waiting-list          503-9012277           8658.0          BR-AC
# 8           Website          750-4705041          82272.0          BR-MS
# 9          Facebook          132-3263001          96889.0          BR-PE
#
#    shipping_zip_code                                 profile_tags  \
# 0              17528                      {'tags': ['n19', 'n8']}
# ...

# %% [markdown]
# ## Excluir dados criptografados e identificador de cliente

# %%
# verificando se é possível excluir por tipo
clientes.select_dtypes(include='object')
# Out:
#                                         ids target_default  \
# 0      343b7e7b-2cf8-e508-b8fd-0a0285af30aa          False
# 1      bc2c7502-bbad-0f8c-39c3-94e881967124          False
# 2      669630dd-2e6a-0396-84bf-455e5009c922           True
# 3      d235609e-b6cb-0ccc-a329-d4f12e7ebdc1          False
# 4      9e0eb880-e8f4-3faa-67d8-f5cdd2b3932b          False
# ...                                     ...            ...
# 44995  696cb747-1159-0a29-6731-8c52c6c42f5d          False
# 44996  92cd9b1a-9a8e-43ad-5d96-8e999128b472          False
# 44997  febdd174-cf18-0be1-feb8-38399dd67d9e          False
# 44998  a0a5a872-6165-b939-b711-37d045a0b5a8           True
# 44999  a7504e93-123a-f965-70c6-ab01a0d475f7          False
#
#                         score_1                   score_2  \
# 0      1Rk8w4Ucd5yR3KcqZzLdow==  IOVu8au3ISbo6+zmfnYwMg==
# 1      DGCQep2AE5QRkNCshIAlFQ==  SaamrHMo23l/3TwXOWgVzw==
# 2      DGCQep2AE5QRkNCshIAlFQ==  Fv28Bz0YRTVAT5kl1bAV6g==
# ...

# %% [markdown]
# ### Existem dados que estão criptografados e dados muito particulares. Vamos limpar essas informações para ficar com um dataframe mais conciso de acordo com o objetivo da análise.

# %%
col_index = zip(clientes.columns, range(43))
col_index

# %%
for i, v in col_index:
    print(f"{i}: {v}")
# Out:
# ids: 0
# target_default: 1
# score_1: 2
# score_2: 3
# score_3: 4
# score_4: 5
# score_5: 6
# score_6: 7
# risk_rate: 8
# last_amount_borrowed: 9
# last_borrowed_in_months: 10
# credit_limit: 11
# reason: 12
# income: 13
# facebook_profile: 14
# state: 15
# zip: 16
# channel: 17
# job_name: 18
# real_state: 19
# ok_since: 20
# n_bankruptcies: 21
# n_defaulted_loans: 22
# n_accounts: 23
# n_issues: 24
# application_time_applied: 25
# application_time_in_funnel: 26
# email: 27
# external_data_provider_credit_checks_last_2_year: 28
# external_data_provider_credit_checks_last_month: 29
# external_data_provider_credit_checks_last_year: 30
# external_data_provider_email_seen_before: 31
# external_data_provider_first_name: 32
# external_data_provider_fraud_score: 33
# lat_lon: 34
# marketing_channel: 35
# profile_phone_number: 36
# reported_income: 37
# shipping_state: 38
# shipping_zip_code: 39
# profile_tags: 40
# user_agent: 41
# target_fraud: 42

# %%
drop_columns = [0, 2, 3, 12, 15, 16, 17, 18, 19, 27, 34, 36, 40, 41]
clientes.drop(clientes.columns[drop_columns], axis=1, inplace=True)

# %%
clientes.head()
# Out:
#   target_default  score_3     score_4   score_5     score_6  risk_rate  \
# 0          False    350.0  101.800832  0.259555  108.427273       0.40
# 1          False    370.0   97.062615  0.942655   92.002546       0.24
# 2           True    360.0  100.027073  0.351918  112.892453       0.29
# 3          False    510.0  101.599485  0.987673   94.902491       0.32
# 4          False    500.0   98.474289  0.532539  118.126207       0.18
#
#    last_amount_borrowed  last_borrowed_in_months  credit_limit     income  \
# 0              25033.92                     36.0           0.0   65014.12
# 1                   NaN                      NaN       39726.0  100018.91
# 2               7207.92                     36.0           NaN   65023.65
# 3                   NaN                      NaN       54591.0   68830.01
# 4                   NaN                      NaN           NaN   60011.29
#
#    ... external_data_provider_credit_checks_last_month  \
# ...

# %%
clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 29 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   target_default                                    41741 non-null  object
#  1   score_3                                           44438 non-null  float64
#  2   score_4                                           45000 non-null  float64
#  3   score_5                                           45000 non-null  float64
#  4   score_6                                           45000 non-null  float64
#  5   risk_rate                                         44438 non-null  float64
#  6   last_amount_borrowed                              15044 non-null  float64
#  7   last_borrowed_in_months                           15044 non-null  float64
# ...

# %%
clientes.loc[clientes.target_fraud.notnull()]
# Out:
#       target_default  score_3     score_4   score_5     score_6  risk_rate  \
# 9               True    390.0   97.608652  0.444594  102.905688       0.36
# 31              True    370.0   97.953472  0.673993  122.218040       0.34
# 77              True    360.0   94.518095  0.157421  101.057304       0.23
# 118             True    200.0   99.374286  0.683578  101.135341       0.35
# 136             True    460.0  101.819222  0.892076  111.008175       0.28
# ...              ...      ...         ...       ...         ...        ...
# 44879           True    580.0   98.457047  0.009786  112.377613       0.49
# 44921          False    320.0   98.718279  0.307249   96.882754       0.38
# 44933          False    470.0  101.819836  0.605845  123.247268       0.31
# 44963           True    550.0  104.988175  0.403095  104.523595       0.52
# 44971            NaN    200.0   95.500019  0.765166  113.398429       0.54
#
# ...

# %%
bor_nn = clientes.loc[clientes.last_amount_borrowed.notnull()]
bor_nn = bor_nn.loc[bor_nn.target_fraud.notnull()]

# %%
sn.countplot(x='target_default',data=bor_nn, palette='hls')
# Out:
# <AxesSubplot:xlabel='target_default', ylabel='count'>

# %%
len(clientes.columns)
# Out:
# 29

# %%
clientes.iloc[:10, :10]
# Out:
#   target_default  score_3     score_4   score_5     score_6  risk_rate  \
# 0          False    350.0  101.800832  0.259555  108.427273       0.40
# 1          False    370.0   97.062615  0.942655   92.002546       0.24
# 2           True    360.0  100.027073  0.351918  112.892453       0.29
# 3          False    510.0  101.599485  0.987673   94.902491       0.32
# 4          False    500.0   98.474289  0.532539  118.126207       0.18
# 5          False    300.0  101.837040  0.915389   90.711273       0.44
# 6          False    250.0   98.958914  0.901736  108.609675       0.43
# 7          False    330.0  100.342564  0.491610  115.954187       0.33
# 8          False    510.0   95.201098  0.559745   94.657281       0.33
# 9           True    390.0   97.608652  0.444594  102.905688       0.36
#
#    last_amount_borrowed  last_borrowed_in_months  credit_limit     income
# 0              25033.92                     36.0           0.0   65014.12
# ...

# %%
clientes.iloc[:10, 10:20]
# Out:
#   facebook_profile  ok_since  n_bankruptcies  n_defaulted_loans  n_accounts  \
# 0             True       NaN             0.0                0.0        18.0
# 1            False      50.0             0.0                0.0        14.0
# 2              NaN       NaN             0.0                0.0        10.0
# 3            False       NaN             1.0                0.0        19.0
# 4             True       NaN             0.0                0.0        11.0
# 5            False       NaN             0.0                0.0         9.0
# 6            False       NaN             0.0                0.0         8.0
# 7             True       NaN             0.0                0.0         7.0
# 8             True       NaN             0.0                0.0         8.0
# 9            False       NaN             0.0                0.0         8.0
#
#    n_issues application_time_applied  application_time_in_funnel  \
# 0      18.0                 07:52:34                         444
# ...

# %%
clientes.iloc[:10, 20:25]
# Out:
#    external_data_provider_credit_checks_last_year  \
# 0                                             0.0
# 1                                             0.0
# 2                                             NaN
# 3                                             NaN
# 4                                             1.0
# 5                                             1.0
# 6                                             0.0
# 7                                             0.0
# 8                                             NaN
# 9                                             0.0
#
#    external_data_provider_email_seen_before external_data_provider_first_name  \
# 0                                      51.0                        leidelaura
# 1                                      17.0                          diocezio
# 2                                       9.0                         veralucia
# 3                                      38.0                            venice
# ...

# %%
clientes.iloc[:10, 25:]
# Out:
#    reported_income shipping_state  shipping_zip_code          target_fraud
# 0          57849.0          BR-MT              17528                   NaN
# 1           4902.0          BR-RS              40933                   NaN
# 2         163679.0          BR-RR              50985                   NaN
# 3           1086.0          BR-RN              37825                   NaN
# 4         198618.0          BR-MT              52827                   NaN
# 5         160198.0          BR-SP              55266                   NaN
# 6         132928.0          BR-SP              47408                   NaN
# 7           8658.0          BR-AC              36168                   NaN
# 8          82272.0          BR-MS              49289                   NaN
# 9          96889.0          BR-PE              45389  fraud_friends_family

# %%
clientes.shipping_state.unique()
# Out:
# array(['BR-MT', 'BR-RS', 'BR-RR', 'BR-RN', 'BR-SP', 'BR-AC', 'BR-MS',
#        'BR-PE', 'BR-AM', 'BR-CE', 'BR-SE', 'BR-MA', 'BR-AP', 'BR-BA',
#        'BR-TO', 'BR-RO', 'BR-SC', 'BR-GO', 'BR-PR', 'BR-MG', 'BR-ES',
#        'BR-DF', 'BR-PA', 'BR-PB', 'BR-AL'], dtype=object)

# %%
clientes['state'] = clientes.shipping_state.str.split(pat = '-', n = 1, expand = True)[1]

# %%
clientes
# Out:
#       target_default  score_3     score_4   score_5     score_6  risk_rate  \
# 0              False    350.0  101.800832  0.259555  108.427273       0.40
# 1              False    370.0   97.062615  0.942655   92.002546       0.24
# 2               True    360.0  100.027073  0.351918  112.892453       0.29
# 3              False    510.0  101.599485  0.987673   94.902491       0.32
# 4              False    500.0   98.474289  0.532539  118.126207       0.18
# ...              ...      ...         ...       ...         ...        ...
# 44995          False    280.0   96.379531  0.416693  103.667082       0.17
# 44996          False    370.0   96.124977  0.692196   97.977973       0.27
# 44997          False    280.0  102.377780  0.530938   93.687747       0.30
# 44998           True    240.0  100.476090  0.214697   86.759074       0.37
# 44999          False    530.0  101.095813  0.011369   97.362918       0.31
#
# ...

# %%
clientes.drop(['shipping_state'], axis=1, inplace=True)

# %%
clientes
# Out:
#       target_default  score_3     score_4   score_5     score_6  risk_rate  \
# 0              False    350.0  101.800832  0.259555  108.427273       0.40
# 1              False    370.0   97.062615  0.942655   92.002546       0.24
# 2               True    360.0  100.027073  0.351918  112.892453       0.29
# 3              False    510.0  101.599485  0.987673   94.902491       0.32
# 4              False    500.0   98.474289  0.532539  118.126207       0.18
# ...              ...      ...         ...       ...         ...        ...
# 44995          False    280.0   96.379531  0.416693  103.667082       0.17
# 44996          False    370.0   96.124977  0.692196   97.977973       0.27
# 44997          False    280.0  102.377780  0.530938   93.687747       0.30
# 44998           True    240.0  100.476090  0.214697   86.759074       0.37
# 44999          False    530.0  101.095813  0.011369   97.362918       0.31
#
# ...

# %%
len(clientes.columns)
# Out:
# 29

# %%
clientes.isnull().sum()
# Out:
# target_default                                       3259
# score_3                                               562
# score_4                                                 0
# score_5                                                 0
# score_6                                                 0
# risk_rate                                             562
# last_amount_borrowed                                29956
# last_borrowed_in_months                             29956
# credit_limit                                        13800
# income                                                562
# facebook_profile                                     4458
# ok_since                                            26545
# n_bankruptcies                                        697
# n_defaulted_loans                                     574
# n_accounts                                            562
# n_issues                                            11544
# ...

# %%
clientes.target_default.unique()
# Out:
# array([False, True, nan], dtype=object)

# %% [markdown]
# ## Ainda temos colunas com muitos dados missing e como dependemos da coluna target default para saber se o cliente pode ou não ser fraude, vamos trabalhar somente com os registros que tem essa informação.

# %%
clientes = clientes.dropna(subset=["target_default"])

# %%
clientes.drop(["last_amount_borrowed", 
               "last_borrowed_in_months",
               "facebook_profile" ,
               "ok_since", "target_fraud", 
               "external_data_provider_credit_checks_last_2_year", 
               "external_data_provider_credit_checks_last_year"], axis=1, inplace=True)
clientes.isnull().sum()
# Out:
# /tmp/ipykernel_7386/355324538.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clientes.drop(["last_amount_borrowed",
# target_default                                         0
# score_3                                                0
# score_4                                                0
# score_5                                                0
# score_6                                                0
# risk_rate                                              0
# credit_limit                                       13109
# income                                                 0
# n_bankruptcies                                       135
# n_defaulted_loans                                     12
# n_accounts                                             0
# ...

# %%
clientes.head()
# Out:
#   target_default  score_3     score_4   score_5     score_6  risk_rate  \
# 0          False    350.0  101.800832  0.259555  108.427273       0.40
# 1          False    370.0   97.062615  0.942655   92.002546       0.24
# 2           True    360.0  100.027073  0.351918  112.892453       0.29
# 3          False    510.0  101.599485  0.987673   94.902491       0.32
# 4          False    500.0   98.474289  0.532539  118.126207       0.18
#
#    credit_limit     income  n_bankruptcies  n_defaulted_loans  ...  \
# 0           0.0   65014.12             0.0                0.0  ...
# 1       39726.0  100018.91             0.0                0.0  ...
# 2           NaN   65023.65             0.0                0.0  ...
# 3       54591.0   68830.01             1.0                0.0  ...
# 4           NaN   60011.29             0.0                0.0  ...
#
#    application_time_applied  application_time_in_funnel  \
# 0                  07:52:34                         444
# ...

# %%
clientes.n_issues.value_counts()
# Out:
# 9.0     3019
# 10.0    3006
# 8.0     2917
# 11.0    2732
# 7.0     2490
# 12.0    2345
# 6.0     2037
# 13.0    2005
# 14.0    1631
# 15.0    1380
# 5.0     1335
# 16.0    1103
# 17.0     864
# 4.0      762
# 18.0     648
# 19.0     566
# 20.0     385
# 21.0     314
# 3.0      282
# 22.0     263
# 23.0     194
# 24.0     158
# 2.0       92
# 25.0      86
# 26.0      54
# 27.0      46
# 28.0      29
# 30.0      15
# 29.0      12
# 34.0       7
# 1.0        6
# 36.0       5
# 32.0       5
# 31.0       5
# 37.0       4
# 40.0       3
# 39.0       3
# 42.0       2
# 35.0       2
# 38.0       2
# 49.0       1
# 33.0       1
# 0.0        1
# 41.0       1
# Name: n_issues, dtype: int64

# %%
media = clientes.n_issues.mean().__round__()
clientes.n_issues.fillna(media)
# Out:
# 0        18.0
# 1        14.0
# 2        11.0
# 3        19.0
# 4        11.0
#          ...
# 44995     7.0
# 44996    16.0
# 44997     6.0
# 44998    10.0
# 44999    10.0
# Name: n_issues, Length: 41741, dtype: float64

# %%
clientes.isnull().sum()
# Out:
# target_default                                         0
# score_3                                                0
# score_4                                                0
# score_5                                                0
# score_6                                                0
# risk_rate                                              0
# credit_limit                                       13109
# income                                                 0
# n_bankruptcies                                       135
# n_defaulted_loans                                     12
# n_accounts                                             0
# n_issues                                           10923
# application_time_applied                               0
# application_time_in_funnel                             0
# external_data_provider_credit_checks_last_month        0
# external_data_provider_email_seen_before            2085
# ...

# %%
clientes.credit_limit.value_counts()
# Out:
# 0.0        4903
# 10000.0     133
# 15000.0      86
# 5000.0       79
# 20000.0      72
#            ...
# 50973.0       1
# 36972.0       1
# 84426.0       1
# 54763.0       1
# 17942.0       1
# Name: credit_limit, Length: 19336, dtype: int64

# %%
clientes.credit_limit.fillna(0)
# Out:
# 0            0.0
# 1        39726.0
# 2            0.0
# 3        54591.0
# 4            0.0
#           ...
# 44995    10627.0
# 44996    36262.0
# 44997        0.0
# 44998        0.0
# 44999    17942.0
# Name: credit_limit, Length: 41741, dtype: float64

# %%
clientes.credit_limit.value_counts()
# Out:
# 0.0        4903
# 10000.0     133
# 15000.0      86
# 5000.0       79
# 20000.0      72
#            ...
# 50973.0       1
# 36972.0       1
# 84426.0       1
# 54763.0       1
# 17942.0       1
# Name: credit_limit, Length: 19336, dtype: int64

# %%
sn.countplot(x='target_default', data=clientes)
# Out:
# <AxesSubplot:xlabel='target_default', ylabel='count'>

# %% [markdown]
# ## As bases estão bem desbalanceadas para uma análise, por isso vamos reduzir a nossa amostragem.
# ## Quando for o objetivo da análise for uma variável categórica, esse é um dos primeiros passos.

# %%
frequencia = clientes['target_default'].value_counts()
percentual = clientes['target_default'].value_counts(normalize = True)*100
dist_freq_qualitativas = pd.DataFrame({'Frequência': frequencia, 'Porcentagem(%)': percentual})
dist_freq_qualitativas
# Out:
#        Frequência  Porcentagem(%)
# False       35080       84.042069
# True         6661       15.957931
